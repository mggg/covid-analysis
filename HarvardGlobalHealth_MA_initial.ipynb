# %% [markdown]
# Data TODO:
#   * [DONE] Max. bed/ICU utilization projections (Harvard Global Health)
#     * How will normal utilization patterns change? [(NYTimes: "Around the country, hospitals have begun canceling elective operations and speeding home patients with less critical ailments. Those efforts could increase the number of free beds available for coronavirus patients. In a half-dozen interviews, hospital executives estimated that they could increase their capacity between 20 percent and 70 percent.")](https://www.nytimes.com/interactive/2020/03/17/upshot/hospital-bed-shortages-coronavirus.html)
#   * [TODO - Bhushan] - Dorm capacity of MA universities
#     * Still need to do some filtering here... — pending
#   * [TODO - Use Nick's scripts] Block-level demographic information for MA
#   * [TODO] Estimates of max. hospital/ICU bed utilization per Census block
#     * Use demographic estimates from Imperial College report?
#   * [TODO - Ruth et al.?] Shapefile of critical care centers w/ capacity info (+ # of workers?)
#   * [TODO - Ruth et al.?] Shapefile of university locations
#   * [TODO - Olivia] Transit time/distance between universities and hospitals
#   * [TODO] How many health care workers per hospital bed? Per ICU bed?

# %%
from harvard_scorecards import load_harvard_scenarios
from ed_institutions import load_ed_institutions

# %%
scenarios = load_harvard_scenarios('data/HarvardGlobalHealth')

# %%
scenarios['60_infected_6mo']
# Out:
#                  hrr  total_hosp_beds  total_icu_beds  avail_hosp_beds  \
# 32        Boston, MA          10239.0          1157.0           2548.0
# 261  Springfield, MA           1588.0           195.0            500.0
# 301    Worcester, MA           1525.0           169.0            425.0
#
#      avail_icu_beds  adult_pop  senior_pop  needed_hosp_beds  needed_icu_beds  \
# 32            438.0  4022208.0    782014.0           33540.0           7220.0
# 261            73.0   600306.0    123079.0            5030.0           1089.0
# 301            43.0   652386.0    122123.0            5422.0           1162.0
#
#      normal_hosp_util  normal_icu_util
# 32           0.751148         0.621435
# 261          0.685139         0.625641
# 301          0.721311         0.745562

# %%
ed = load_ed_institutions('data/ma_dorm_capacity.csv', 100000000, 500)

# %%
ed
# Out:
#                                       name  enrollment  capacity  \
# 2                          Amherst College        1855      1837
# 6                       Assumption College        2428      1859
# 7                           Babson College        3357      1890
# 15                      Bentley University        5460      3421
# 16                Berklee College of Music        6963      1409
# 22                          Boston College       14720      7721
# 24                       Boston University       34657     11732
# 25                     Brandeis University        5800      2950
# 34                        Clark University        3122      1664
# 36               College of the Holy Cross        2939      2507
# 38                           Curry College        2580      1543
# 45                         Emerson College        4573      1953
# 46                        Emmanuel College        2209      1395
# ...
